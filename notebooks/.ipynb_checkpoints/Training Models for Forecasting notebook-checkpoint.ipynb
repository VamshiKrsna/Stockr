# %% [markdown]
# # Notebook for testing out various models

# %% [markdown]
# ### Models to Test :
# * ARIMA
# * SARIMAX
# * Prophet (formerly FBProphet)
# * Random Forest & XGBoost
# * LSTM
# * GRU
# * Transformer Models - BERT

# %%
# !pip install xgboost
# !pip install prophet
# !pip install torch
# !pip install lightgbm

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from prophet import Prophet
import torch

# %% [markdown]
# ## Data

# %%
data = pd.read_csv("../data/MSFT.csv")
data.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  4624.000000  4624.000000  4624.000000  4624.000000  4.624000e+03
# mean     97.668328    98.619755    96.685851    97.700532  4.366770e+07
# std     108.590577   109.614455   107.505575   108.623913  2.823090e+07
# min      11.300617    11.612869    11.055273    11.263444  7.425600e+06
# 25%      21.461364    21.622073    21.249248    21.470862  2.491638e+07
# 50%      39.905392    40.232631    39.613691    39.945400  3.599870e+07
# 75%     137.909078   138.920999   136.130181   137.602905  5.406152e+07
# max     440.850006   443.399994   439.369995   441.579987  5.910522e+08
#
#          Dividends  Stock Splits          S_3          S_9         S_18  ...  \
# count  4624.000000        4624.0  4624.000000  4624.000000  4624.000000  ...
# mean      0.005433           0.0    97.609331    97.342446    96.949257  ...
# std       0.049509           0.0   108.500639   108.165280   107.683656  ...
# min       0.000000           0.0    11.325397    11.774779    12.167161  ...
# 25%       0.000000           0.0    21.437578    21.443549    21.446988  ...
# 50%       0.000000           0.0    39.904752    39.968142    39.665544  ...
# 75%       0.000000           0.0   137.679462   137.515890   135.500306  ...
# max       0.750000           0.0   438.439992   427.239997   426.472778  ...
#
#                RSI  Bollinger_Mid  Bollinger_Upper  Bollinger_Lower  \
# count  4624.000000    4624.000000      4624.000000      4624.000000
# mean     54.807419      96.861425       101.770685        91.952165
# std      15.826388     107.574763       113.063351       102.185167
# min       6.806087      12.228455        13.246611        10.709566
# 25%      43.528815      21.458546        22.347419        20.431160
# 50%      54.958045      39.629939        41.709249        37.576867
# 75%      66.380397     135.332242       140.676410       128.992797
# max      99.112239     425.885500       441.545030       415.076599
#
#        Volume_Rolling_Mean  Volume_Change  Overall_Mean  Overall_Min  \
# count         4.624000e+03    4624.000000   4624.000000  4624.000000
# mean          4.370419e+07       0.057563     97.452772    11.263444
# std           2.351244e+07       0.404716      0.000000     0.000000
# min           1.346000e+07      -0.808979     97.452772    11.263444
# 25%           2.631419e+07      -0.178469     97.452772    11.263444
# 50%           3.733673e+07      -0.013001     97.452772    11.263444
# 75%           5.569644e+07       0.204908     97.452772    11.263444
# max           2.678342e+08       6.234345     97.452772    11.263444
#
#         Overall_Max       Target
# count  4.624000e+03  4624.000000
# mean   4.425700e+02    97.791951
# std    5.684957e-14   108.736203
# min    4.425700e+02    11.263444
# 25%    4.425700e+02    21.472810
# 50%    4.425700e+02    39.958326
# 75%    4.425700e+02   137.877998
# max    4.425700e+02   442.570007
#
# [8 rows x 30 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4624 entries, 0 to 4623
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 4624 non-null   object
#  1   Open                 4624 non-null   float64
#  2   High                 4624 non-null   float64
#  3   Low                  4624 non-null   float64
#  4   Close                4624 non-null   float64
#  5   Volume               4624 non-null   int64
#  6   Dividends            4624 non-null   float64
#  7   Stock Splits         4624 non-null   float64
#  8   S_3                  4624 non-null   float64
#  9   S_9                  4624 non-null   float64
#  10  S_18                 4624 non-null   float64
#  11  lag_1                4624 non-null   float64
#  12  lag_2                4624 non-null   float64
#  13  lag_3                4624 non-null   float64
#  14  Rolling_Mean         4624 non-null   float64
#  15  Rolling_Min          4624 non-null   float64
#  16  Rolling_Max          4624 non-null   float64
#  17  EMA_12               4624 non-null   float64
#  18  EMA_26               4624 non-null   float64
#  19  MACD                 4624 non-null   float64
#  20  MACD_Signal          4624 non-null   float64
#  21  RSI                  4624 non-null   float64
#  22  Bollinger_Mid        4624 non-null   float64
#  23  Bollinger_Upper      4624 non-null   float64
#  24  Bollinger_Lower      4624 non-null   float64
#  25  Volume_Rolling_Mean  4624 non-null   float64
#  26  Volume_Change        4624 non-null   float64
#  27  Overall_Mean         4624 non-null   float64
#  28  Overall_Min          4624 non-null   float64
#  29  Overall_Max          4624 non-null   float64
#  30  Target               4624 non-null   float64
# dtypes: float64(29), int64(1), object(1)
# memory usage: 1.1+ MB

# %%
data
# Out:
#                            Date        Open        High         Low  \
# 0     2006-01-31 00:00:00-05:00   19.679359   20.010756   19.651156
# 1     2006-02-01 00:00:00-05:00   19.714613   19.792175   19.573594
# 2     2006-02-02 00:00:00-05:00   19.721664   19.735766   19.425521
# 3     2006-02-03 00:00:00-05:00   19.376171   19.531294   19.277457
# 4     2006-02-06 00:00:00-05:00   19.397323   19.418477   19.101181
# ...                         ...         ...         ...         ...
# 4619  2024-06-07 00:00:00-04:00  426.200012  426.279999  423.000000
# 4620  2024-06-10 00:00:00-04:00  424.700012  428.079987  423.890015
# 4621  2024-06-11 00:00:00-04:00  425.480011  432.820007  425.250000
# 4622  2024-06-12 00:00:00-04:00  435.320007  443.399994  433.250000
# 4623  2024-06-13 00:00:00-04:00  440.850006  443.390015  439.369995
#
#            Close    Volume  Dividends  Stock Splits         S_3         S_9  \
# 0      19.848583  94841300        0.0           0.0   19.728718   19.029883
# 1      19.771023  68448800        0.0           0.0   19.787475   19.109795
# 2      19.517185  55073400        0.0           0.0   19.712264   19.209293
# 3      19.418478  75022700        0.0           0.0   19.568895   19.302523
# 4      19.157589  60170500        0.0           0.0   19.364417   19.372250
# ...          ...       ...        ...           ...         ...         ...
# 4619  423.850006  13621700        0.0           0.0  424.126668  421.251116
# 4620  427.869995  14003000        0.0           0.0  425.413330  420.978892
# 4621  432.679993  14551100        0.0           0.0  428.133331  421.368890
# 4622  441.059998  22366200        0.0           0.0  433.869995  424.301110
# 4623  441.579987  15960600        0.0           0.0  438.439992  427.239997
#
#       ...        RSI  Bollinger_Mid  Bollinger_Upper  Bollinger_Lower  \
# 0     ...  65.753580      19.034545        19.762916        18.306173
# 1     ...  60.807054      19.076851        19.873499        18.280204
# 2     ...  57.336928      19.101882        19.921677        18.282087
# 3     ...  54.642099      19.121273        19.952245        18.290300
# 4     ...  52.284319      19.130439        19.958623        18.302255
# ...   ...        ...            ...              ...              ...
# 4619  ...  53.910632     422.018918       434.639662       409.398174
# 4620  ...  52.784505     422.712755       434.997026       410.428483
# 4621  ...  53.910602     423.698000       435.854008       411.541992
# 4622  ...  59.861540     424.960500       438.795929       411.125070
# 4623  ...  64.452810     425.885500       441.545030       410.225969
#
#       Volume_Rolling_Mean  Volume_Change  Overall_Mean  Overall_Min  \
# 0              92388520.0      -0.088057     97.452772    11.263444
# 1              94263860.0      -0.278281     97.452772    11.263444
# 2              91376680.0      -0.195407     97.452772    11.263444
# 3              79477080.0       0.362231     97.452772    11.263444
# 4              70711340.0      -0.197969     97.452772    11.263444
# ...                   ...            ...           ...          ...
# 4619           15460920.0      -0.083411     97.452772    11.263444
# 4620           14764580.0       0.027992     97.452772    11.263444
# 4621           14805020.0       0.039142     97.452772    11.263444
# 4622           15880660.0       0.537080     97.452772    11.263444
# 4623           16100520.0      -0.286396     97.452772    11.263444
#
#       Overall_Max      Target
# 0      442.570007   19.771023
# 1      442.570007   19.517185
# 2      442.570007   19.418478
# 3      442.570007   19.157589
# 4      442.570007   18.995409
# ...           ...         ...
# 4619   442.570007  427.869995
# 4620   442.570007  432.679993
# 4621   442.570007  441.059998
# 4622   442.570007  441.579987
# 4623   442.570007  442.570007
#
# [4624 rows x 31 columns]

# %% [markdown]
# ## Data Preparation For ARIMA

# %%
arima_data = data[['Date','Close']]
print(arima_data)
# Out:
#                            Date       Close
# 0     2006-01-31 00:00:00-05:00   19.848583
# 1     2006-02-01 00:00:00-05:00   19.771023
# 2     2006-02-02 00:00:00-05:00   19.517185
# 3     2006-02-03 00:00:00-05:00   19.418478
# 4     2006-02-06 00:00:00-05:00   19.157589
# ...                         ...         ...
# 4619  2024-06-07 00:00:00-04:00  423.850006
# 4620  2024-06-10 00:00:00-04:00  427.869995
# 4621  2024-06-11 00:00:00-04:00  432.679993
# 4622  2024-06-12 00:00:00-04:00  441.059998
# 4623  2024-06-13 00:00:00-04:00  441.579987
#
# [4624 rows x 2 columns]

# %%
train_data = arima_data.iloc[:-90]
test_data = arima_data.iloc[-90:]
# Out:
#                            Date       Close
# 0     2006-01-31 00:00:00-05:00   19.848583
# 1     2006-02-01 00:00:00-05:00   19.771023
# 2     2006-02-02 00:00:00-05:00   19.517185
# 3     2006-02-03 00:00:00-05:00   19.418478
# 4     2006-02-06 00:00:00-05:00   19.157589
# ...                         ...         ...
# 4529  2024-01-30 00:00:00-05:00  407.101501
# 4530  2024-01-31 00:00:00-05:00  396.131622
# 4531  2024-02-01 00:00:00-05:00  402.309052
# 4532  2024-02-02 00:00:00-05:00  409.721954
# 4533  2024-02-05 00:00:00-05:00  404.172241
#
# [4534 rows x 2 columns]

# %% [markdown]
# ### ARIMA

# %%
model = ARIMA(train_data["Close"], order = (1,1,1))
model_fit = model.fit()
forecast = model_fit.forecast(steps = 90) # Predicting the next 90 days movement
print(forecast)
# Out:
# 4534    404.445850
# 4535    404.513645
# 4536    404.530443
# 4537    404.534606
# 4538    404.535637
#            ...
# 4619    404.535977
# 4620    404.535977
# 4621    404.535977
# 4622    404.535977
# 4623    404.535977
# Name: predicted_mean, Length: 90, dtype: float64

# %%
plt.plot(series, label='Original Data')
plt.plot(np.arange(len(series), len(series) + len(forecast)), forecast, label='Forecasted Values')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('ARIMA Forecast')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 plt.plot(series, label='Original Data')
#       2 plt.plot(np.arange(len(series), len(series) + len(forecast)), forecast, label='Forecasted Values')
#       3 plt.xlabel('Time')
#
# NameError: name 'series' is not defined
