# %% [markdown]
# # Notebook for testing out various models

# %% [markdown]
# ### Models to Test :
# * ARIMA
# * SARIMAX
# * Prophet (formerly FBProphet)
# * Random Forest & XGBoost
# * LSTM
# * GRU
# * Transformer Models - BERT

# %%
# !pip install xgboost
# !pip install prophet
# !pip install torch
# !pip install lightgbm

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from xgboost import XGBRegressor
from prophet import Prophet
import torch

# %% [markdown]
# ## Data

# %%
data = pd.read_csv("../data/MSFT.csv")
data.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  4628.000000  4628.000000  4628.000000  4628.000000  4.628000e+03
# mean     97.955189    98.910500    96.971064    98.081905  4.368892e+07
# std     108.974136   110.004939   107.888864   109.128267  2.826966e+07
# min      11.321001    11.633818    11.075216    11.283761  7.425600e+06
# 25%      21.497524    21.656163    21.284262    21.509594  2.491118e+07
# 50%      39.977358    40.305183    39.685150    40.030407  3.599870e+07
# 75%     138.313646   139.715566   136.777445   138.236942  5.406520e+07
# max     442.589996   450.940002   440.720001   448.369995  5.910522e+08
#
#                Day    DayOfWeek      Quarter        Month         Year  ...  \
# count  4628.000000  4628.000000  4628.000000  4628.000000  4628.000000  ...
# mean     15.724935     2.023984     2.493518     6.485523  2014.767070  ...
# std       8.755582     1.399028     1.113681     3.419077     5.315157  ...
# min       1.000000     0.000000     1.000000     1.000000  2006.000000  ...
# 25%       8.000000     1.000000     2.000000     4.000000  2010.000000  ...
# 50%      16.000000     2.000000     2.000000     6.000000  2015.000000  ...
# 75%      23.000000     3.000000     3.000000     9.000000  2019.000000  ...
# max      31.000000     4.000000     4.000000    12.000000  2024.000000  ...
#
#        Rolling_Min  Rolling_Max       EMA_12       EMA_26    MACD  \
# count  4628.000000  4628.000000  4628.000000  4628.000000  4628.0
# mean     96.878388    98.908216    97.496620    97.496620     0.0
# std     107.777817   110.011578   108.366746   108.366746     0.0
# min      11.283761    11.380585    12.070885    12.070885     0.0
# 25%      21.303935    21.642164    21.474782    21.474782     0.0
# 50%      39.652710    40.360760    39.916460    39.916460     0.0
# 75%     134.335438   138.622772   137.553714   137.553714     0.0
# max     441.579987   448.369995   433.735117   433.735117     0.0
#
#        MACD_Signal          RSI  Overall_Mean  Overall_Min  Overall_Max
# count       4628.0  4628.000000   4628.000000  4628.000000  4628.000000
# mean           0.0    54.814277     97.775456    11.283761   448.369995
# std            0.0    15.821376      0.000000     0.000000     0.000000
# min            0.0     6.806019     97.775456    11.283761   448.369995
# 25%            0.0    43.544649     97.775456    11.283761   448.369995
# 50%            0.0    54.971384     97.775456    11.283761   448.369995
# 75%            0.0    66.380397     97.775456    11.283761   448.369995
# max            0.0    99.111514     97.775456    11.283761   448.369995
#
# [8 rows x 27 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4628 entries, 0 to 4627
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          4628 non-null   object
#  1   Open          4628 non-null   float64
#  2   High          4628 non-null   float64
#  3   Low           4628 non-null   float64
#  4   Close         4628 non-null   float64
#  5   Volume        4628 non-null   int64
#  6   Day           4628 non-null   int64
#  7   DayOfWeek     4628 non-null   int64
#  8   Quarter       4628 non-null   int64
#  9   Month         4628 non-null   int64
#  10  Year          4628 non-null   int64
#  11  S_3           4628 non-null   float64
#  12  S_9           4628 non-null   float64
#  13  S_18          4628 non-null   float64
#  14  lag_1         4628 non-null   float64
#  15  lag_2         4628 non-null   float64
#  16  lag_3         4628 non-null   float64
#  17  Rolling_Mean  4628 non-null   float64
#  18  Rolling_Min   4628 non-null   float64
#  19  Rolling_Max   4628 non-null   float64
#  20  EMA_12        4628 non-null   float64
#  21  EMA_26        4628 non-null   float64
#  22  MACD          4628 non-null   float64
#  23  MACD_Signal   4628 non-null   float64
#  24  RSI           4628 non-null   float64
#  25  Overall_Mean  4628 non-null   float64
#  26  Overall_Min   4628 non-null   float64
#  27  Overall_Max   4628 non-null   float64
# dtypes: float64(21), int64(6), object(1)
# memory usage: 1012.5+ KB

# %%
data
# Out:
#                            Date        Open        High         Low  \
# 0     2006-01-27 05:00:00+00:00   19.234521   19.743110   19.206267
# 1     2006-01-30 05:00:00+00:00   19.651289   19.905584   19.623035
# 2     2006-01-31 05:00:00+00:00   19.714849   20.046844   19.686595
# 3     2006-02-01 05:00:00+00:00   19.750170   19.827871   19.608896
# 4     2006-02-02 05:00:00+00:00   19.757235   19.771362   19.460558
# ...                         ...         ...         ...         ...
# 4623  2024-06-11 04:00:00+00:00  425.480011  432.820007  425.250000
# 4624  2024-06-12 04:00:00+00:00  435.320007  443.399994  433.250000
# 4625  2024-06-13 04:00:00+00:00  440.850006  443.390015  439.369995
# 4626  2024-06-14 04:00:00+00:00  438.279999  443.140015  436.720001
# 4627  2024-06-17 04:00:00+00:00  442.589996  450.940002  440.720001
#
#            Close     Volume  Day  DayOfWeek  Quarter  Month  ...  Rolling_Min  \
# 0      19.778437  134520700   27          4        1      1  ...    18.648235
# 1      19.884378  103999200   30          0        1      1  ...    18.718876
# 2      19.806681   94841300   31          1        1      1  ...    19.630091
# 3      19.552387   68448800    1          2        1      2  ...    19.778437
# 4      19.453501   55073400    2          3        1      2  ...    19.552387
# ...          ...        ...  ...        ...      ...    ...  ...          ...
# 4623  441.059998   14551100   11          1        2      6  ...   423.850006
# 4624  441.579987   22366200   12          2        2      6  ...   427.869995
# 4625  442.570007   15960600   13          3        2      6  ...   432.679993
# 4626  448.369995   13582000   14          4        2      6  ...   441.059998
# 4627  446.339996   20790000   17          0        2      6  ...   441.579987
#
#       Rolling_Max      EMA_12      EMA_26  MACD  MACD_Signal        RSI  \
# 0       19.630091   18.951475   18.951475   0.0          0.0  62.643770
# 1       19.778437   19.078700   19.078700   0.0          0.0  65.659794
# 2       19.884378   19.202651   19.202651   0.0          0.0  65.753562
# 3       19.884378   19.295578   19.295578   0.0          0.0  60.807027
# 4       19.884378   19.335087   19.335087   0.0          0.0  57.337032
# ...           ...         ...         ...   ...          ...        ...
# 4623   432.679993  424.081913  424.081913   0.0          0.0  53.910602
# 4624   441.059998  426.693926  426.693926   0.0          0.0  59.861540
# 4625   441.579987  428.984089  428.984089   0.0          0.0  64.452810
# 4626   442.570007  431.074231  431.074231   0.0          0.0  62.854782
# 4627   448.369995  433.735117  433.735117   0.0          0.0  66.740861
#
#       Overall_Mean  Overall_Min  Overall_Max
# 0        97.775456    11.283761   448.369995
# 1        97.775456    11.283761   448.369995
# 2        97.775456    11.283761   448.369995
# 3        97.775456    11.283761   448.369995
# 4        97.775456    11.283761   448.369995
# ...            ...          ...          ...
# 4623     97.775456    11.283761   448.369995
# 4624     97.775456    11.283761   448.369995
# 4625     97.775456    11.283761   448.369995
# 4626     97.775456    11.283761   448.369995
# 4627     97.775456    11.283761   448.369995
#
# [4628 rows x 28 columns]

# %% [markdown]
# ## Data Preparation For ARIMA

# %%
arima_data = data[['Date','Close']]
print(arima_data)
# Out:
#                            Date       Close
# 0     2006-01-27 05:00:00+00:00   19.778437
# 1     2006-01-30 05:00:00+00:00   19.884378
# 2     2006-01-31 05:00:00+00:00   19.806681
# 3     2006-02-01 05:00:00+00:00   19.552387
# 4     2006-02-02 05:00:00+00:00   19.453501
# ...                         ...         ...
# 4623  2024-06-11 04:00:00+00:00  441.059998
# 4624  2024-06-12 04:00:00+00:00  441.579987
# 4625  2024-06-13 04:00:00+00:00  442.570007
# 4626  2024-06-14 04:00:00+00:00  448.369995
# 4627  2024-06-17 04:00:00+00:00  446.339996
#
# [4628 rows x 2 columns]

# %%
train_data = arima_data.iloc[:-90]
test_data = arima_data.iloc[-90:]

# %% [markdown]
# ### ARIMA

# %%
model = ARIMA(train_data["Close"], order = (1,1,1))
model_fit = model.fit()
forecast = model_fit.forecast(steps = 90) # Predicting the next 90 days movement
forecast
# Out:
# 4538    413.042258
# 4539    412.966869
# 4540    412.948134
# 4541    412.943478
# 4542    412.942321
#            ...
# 4623    412.941938
# 4624    412.941938
# 4625    412.941938
# 4626    412.941938
# 4627    412.941938
# Name: predicted_mean, Length: 90, dtype: float64

# %%
# Evaluation : 
rmse = np.sqrt(mean_squared_error(forecast,test_data['Close']))
print("Root Mean Squared Error : ",rmse) #12.104453670429674
mae = mean_absolute_error(forecast,test_data['Close'])
print("Mean Absolute Error : ",mae) #9.552664868036269
# Model's performance is real bad
# Out:
# Root Mean Squared Error :  12.104453670429674
# Mean Absolute Error :  9.552664868036269

# %%
print(test_data)
print(forecast)
# Out:
#                            Date       Close
# 4538  2024-02-08 05:00:00+00:00  419.773712
# 4539  2024-02-09 05:00:00+00:00  414.493500
# 4540  2024-02-12 05:00:00+00:00  405.570007
# 4541  2024-02-13 05:00:00+00:00  409.489990
# 4542  2024-02-14 05:00:00+00:00  406.559998
# ...                         ...         ...
# 4623  2024-06-11 04:00:00+00:00  441.059998
# 4624  2024-06-12 04:00:00+00:00  441.579987
# 4625  2024-06-13 04:00:00+00:00  442.570007
# 4626  2024-06-14 04:00:00+00:00  448.369995
# 4627  2024-06-17 04:00:00+00:00  446.339996
#
# [90 rows x 2 columns]
# 4538    413.042258
# 4539    412.966869
# 4540    412.948134
# 4541    412.943478
# 4542    412.942321
#            ...
# 4623    412.941938
# 4624    412.941938
# 4625    412.941938
# 4626    412.941938
# 4627    412.941938
# Name: predicted_mean, Length: 90, dtype: float64

# %%
# Convert RangeIndex objects to Series
test_data_dates = pd.Series(test_data.index)
forecast_dates = pd.date_range(start=test_data.index[-1], periods=90, freq='D')
forecast_dates = pd.Series(forecast_dates)

forecast_dates = pd.concat([test_data_dates, forecast_dates])

plt.plot(test_data["Close"], label='Actual')
plt.plot(forecast, label='Forecast')

plt.legend()
plt.show()

# %% [markdown]
# ### Random Forest Regressor with XGBoost

# %%
data
# Out:
#                            Date        Open        High         Low  \
# 0     2006-01-03 00:00:00-05:00   18.542274   19.072053   18.436319
# 1     2006-01-04 00:00:00-05:00   18.909593   19.128568   18.909593
# 2     2006-01-05 00:00:00-05:00   19.043803   19.163887   19.008485
# 3     2006-01-06 00:00:00-05:00   18.994350   19.072052   18.711802
# 4     2006-01-09 00:00:00-05:00   19.022611   19.121503   18.902528
# ...                         ...         ...         ...         ...
# 4641  2024-06-12 00:00:00-04:00  435.320007  443.399994  433.250000
# 4642  2024-06-13 00:00:00-04:00  440.850006  443.390015  439.369995
# 4643  2024-06-14 00:00:00-04:00  438.279999  443.140015  436.720001
# 4644  2024-06-17 00:00:00-04:00  442.589996  450.940002  440.720001
# 4645  2024-06-18 00:00:00-04:00  449.709991  450.140015  444.890015
#
#            Close     Volume  Dividends  Stock Splits
# 0      18.959034   79973000        0.0           0.0
# 1      19.050867   57975600        0.0           0.0
# 2      19.064995   48245500        0.0           0.0
# 3      19.008478  100963000        0.0           0.0
# 4      18.973166   55625000        0.0           0.0
# ...          ...        ...        ...           ...
# 4641  441.059998   22366200        0.0           0.0
# 4642  441.579987   15960600        0.0           0.0
# 4643  442.570007   13582000        0.0           0.0
# 4644  448.369995   20790000        0.0           0.0
# 4645  446.339996   17085700        0.0           0.0
#
# [4646 rows x 8 columns]

# %%
rfr_X = data.drop(["Close","Date"],axis = 1)
rfr_y = data["Close"]
X_train, X_test, y_train, y_test = train_test_split(rfr_X,rfr_y,test_size = 0.3,random_state = 101,shuffle = False)

# %%
rfr = RandomForestRegressor()
rfr.fit(X_train,y_train)
rfr
# Out:
# RandomForestRegressor()

# %%
forecast_preds = rfr.predict(X_test)
forecast_preds
# Out:
# array([106.09292496, 105.02068398, 101.32109741, ..., 108.7508606 ,
#        108.69999313, 108.7508606 ])

# %%
# plt.plot(data["Date"], data["Close"], label='Historical')

# plt.plot(data["Date"][-len(forecast_preds):], forecast_preds, label='Forecast')

# plt.legend()
# plt.show()

# %%
data.head()
# Out:
#                         Date       Open       High        Low      Close  \
# 0  2006-01-03 00:00:00-05:00  18.542274  19.072053  18.436319  18.959034
# 1  2006-01-04 00:00:00-05:00  18.909593  19.128568  18.909593  19.050867
# 2  2006-01-05 00:00:00-05:00  19.043803  19.163887  19.008485  19.064995
# 3  2006-01-06 00:00:00-05:00  18.994350  19.072052  18.711802  19.008478
# 4  2006-01-09 00:00:00-05:00  19.022611  19.121503  18.902528  18.973166
#
#       Volume  Dividends  Stock Splits
# 0   79973000        0.0           0.0
# 1   57975600        0.0           0.0
# 2   48245500        0.0           0.0
# 3  100963000        0.0           0.0
# 4   55625000        0.0           0.0
